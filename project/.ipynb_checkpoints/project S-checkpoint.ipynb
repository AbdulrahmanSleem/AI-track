# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

from datetime import datetime

# %%
tmdb_data = pd.read_csv('tmdb-movies.csv')
tmdb_data.head()
# Out:
#        id    imdb_id  popularity     budget     revenue
# 0  135397  tt0369610   32.985763  150000000  1513528810  \
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title
# 0                Jurassic World  \
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  \
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director
# 0                      http://www.jurassicworld.com/   Colin Trevorrow  \
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline  ...
# 0              The park is open.  ...  \
# 1             What a Lovely Day.  ...
# 2     One Choice Can Destroy You  ...
# 3  Every generation has a story.  ...
# 4            Vengeance Hits Home  ...
#
#                                             overview runtime
# 0  Twenty-two years after the events of Jurassic ...     124  \
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres
# 0  Action|Adventure|Science Fiction|Thriller  \
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562  \
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15       5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15       2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09
#
# [5 rows x 21 columns]

# %%
tmdb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
#  15  release_date          10866 non-null  object
#  16  vote_count            10866 non-null  int64
#  17  vote_average          10866 non-null  float64
#  18  release_year          10866 non-null  int64
#  19  budget_adj            10866 non-null  float64
#  20  revenue_adj           10866 non-null  float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %%
tmdb_data.shape
# Out:
# (10866, 21)

# %%
tmdb_data.drop(labels = ['id', 'imdb_id', 'budget_adj', 'revenue_adj', 'homepage', 'keywords', 'overview', 'production_companies', 'vote_count', 'vote_average'],axis =1,inplace =True)
tmdb_data.head()
# Out:
#    popularity     budget     revenue                original_title
# 0   32.985763  150000000  1513528810                Jurassic World  \
# 1   28.419936  150000000   378436354            Mad Max: Fury Road
# 2   13.112507  110000000   295238201                     Insurgent
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow  \
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  runtime
# 0              The park is open.      124  \
# 1             What a Lovely Day.      120
# 2     One Choice Can Destroy You      119
# 3  Every generation has a story.      136
# 4            Vengeance Hits Home      137
#
#                                       genres release_date  release_year
# 0  Action|Adventure|Science Fiction|Thriller       6/9/15          2015
# 1  Action|Adventure|Science Fiction|Thriller      5/13/15          2015
# 2         Adventure|Science Fiction|Thriller      3/18/15          2015
# 3   Action|Adventure|Science Fiction|Fantasy     12/15/15          2015
# 4                      Action|Crime|Thriller       4/1/15          2015

# %%
tmdb_data.dtypes
# Out:
# popularity        float64
# budget              int64
# revenue             int64
# original_title     object
# cast               object
# director           object
# tagline            object
# runtime             int64
# genres             object
# release_date       object
# release_year        int64
# dtype: object

# %%
tmdb_data.drop_duplicates(inplace=True)
tmdb_data.duplicated().sum()
# Out:
# 0

# %%
temp_list=['budget', 'revenue']
tmdb_data[temp_list] = tmdb_data[temp_list].replace(0, np.NAN)
tmdb_data.dropna(subset = temp_list, inplace = True)
tmdb_data.describe()
# Out:
#         popularity        budget       revenue      runtime  release_year
# count  3854.000000  3.854000e+03  3.854000e+03  3854.000000   3854.000000
# mean      1.191554  3.720370e+07  1.076866e+08   109.220291   2001.261028
# std       1.475162  4.220822e+07  1.765393e+08    19.922820     11.282575
# min       0.001117  1.000000e+00  2.000000e+00    15.000000   1960.000000
# 25%       0.462367  1.000000e+07  1.360003e+07    95.000000   1995.000000
# 50%       0.797511  2.400000e+07  4.480000e+07   106.000000   2004.000000
# 75%       1.368324  5.000000e+07  1.242125e+08   119.000000   2010.000000
# max      32.985763  4.250000e+08  2.781506e+09   338.000000   2015.000000

# %%
tmdb_data.head()
# Out:
#    popularity       budget       revenue                original_title
# 0   32.985763  150000000.0  1.513529e+09                Jurassic World  \
# 1   28.419936  150000000.0  3.784364e+08            Mad Max: Fury Road
# 2   13.112507  110000000.0  2.952382e+08                     Insurgent
# 3   11.173104  200000000.0  2.068178e+09  Star Wars: The Force Awakens
# 4    9.335014  190000000.0  1.506249e+09                     Furious 7
#
#                                                 cast          director
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow  \
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  runtime
# 0              The park is open.      124  \
# 1             What a Lovely Day.      120
# 2     One Choice Can Destroy You      119
# 3  Every generation has a story.      136
# 4            Vengeance Hits Home      137
#
#                                       genres release_date  release_year
# 0  Action|Adventure|Science Fiction|Thriller       6/9/15          2015
# 1  Action|Adventure|Science Fiction|Thriller      5/13/15          2015
# 2         Adventure|Science Fiction|Thriller      3/18/15          2015
# 3   Action|Adventure|Science Fiction|Fantasy     12/15/15          2015
# 4                      Action|Crime|Thriller       4/1/15          2015

# %%
tmdb_data.release_date = pd.to_datetime(tmdb_data['release_date'])
tmdb_data.head()
# Out:
# C:\Users\shyma\AppData\Local\Temp\ipykernel_36656\2631358094.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   tmdb_data.release_date = pd.to_datetime(tmdb_data['release_date'])
#    popularity       budget       revenue                original_title
# 0   32.985763  150000000.0  1.513529e+09                Jurassic World  \
# 1   28.419936  150000000.0  3.784364e+08            Mad Max: Fury Road
# 2   13.112507  110000000.0  2.952382e+08                     Insurgent
# 3   11.173104  200000000.0  2.068178e+09  Star Wars: The Force Awakens
# 4    9.335014  190000000.0  1.506249e+09                     Furious 7
#
#                                                 cast          director
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow  \
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  runtime
# 0              The park is open.      124  \
# 1             What a Lovely Day.      120
# 2     One Choice Can Destroy You      119
# 3  Every generation has a story.      136
# 4            Vengeance Hits Home      137
#
#                                       genres release_date  release_year
# 0  Action|Adventure|Science Fiction|Thriller   2015-06-09          2015
# 1  Action|Adventure|Science Fiction|Thriller   2015-05-13          2015
# 2         Adventure|Science Fiction|Thriller   2015-03-18          2015
# 3   Action|Adventure|Science Fiction|Fantasy   2015-12-15          2015
# 4                      Action|Crime|Thriller   2015-04-01          2015

# %%
tmdb_data['runtime'] =tmdb_data['runtime'].replace(0, np.NAN)
tmdb_data.dtypes
# Out:
# popularity               float64
# budget                   float64
# revenue                  float64
# original_title            object
# cast                      object
# director                  object
# tagline                   object
# runtime                    int64
# genres                    object
# release_date      datetime64[ns]
# release_year               int64
# dtype: object

# %%
change_type=['budget', 'revenue']
tmdb_data[change_type]=tmdb_data[change_type].applymap(np.int64)
tmdb_data.dtypes
# Out:
# popularity               float64
# budget                     int64
# revenue                    int64
# original_title            object
# cast                      object
# director                  object
# tagline                   object
# runtime                    int64
# genres                    object
# release_date      datetime64[ns]
# release_year               int64
# dtype: object

# %%
tmdb_data.to_csv('tmdb-movies-new.csv', index= False)

# %%
df = pd.read_csv('tmdb-movies-new.csv')

# %%
tmdb_data.hist(figsize = (10, 10));

# %% [markdown]
# ## 1-Movies which had most and least profit

# %%
# making profit column to know profit of each movie
tmdb_data['profit']=tmdb_data['revenue']-tmdb_data['budget']
tmdb_data
# Out:
#        popularity     budget     revenue                   original_title
# 0       32.985763  150000000  1513528810                   Jurassic World  \
# 1       28.419936  150000000   378436354               Mad Max: Fury Road
# 2       13.112507  110000000   295238201                        Insurgent
# 3       11.173104  200000000  2068178225     Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                        Furious 7
# ...           ...        ...         ...                              ...
# 10822    0.670274    7500000    33736689  Who's Afraid of Virginia Woolf?
# 10828    0.402730    3000000    13000000                     Torn Curtain
# 10829    0.395668    4653000     6000000                        El Dorado
# 10835    0.299911   12000000    20000000                 The Sand Pebbles
# 10848    0.207257    5115000    12000000                 Fantastic Voyage
#
#                                                     cast           director
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...    Colin Trevorrow  \
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...      George Miller
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...   Robert Schwentke
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...        J.J. Abrams
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...          James Wan
# ...                                                  ...                ...
# 10822  Elizabeth Taylor|Richard Burton|George Segal|S...       Mike Nichols
# 10828  Paul Newman|Julie Andrews|Lila Kedrova|HansjÃ¶...   Alfred Hitchcock
# 10829  John Wayne|Robert Mitchum|James Caan|Charlene ...       Howard Hawks
# 10835  Steve McQueen|Richard Attenborough|Richard Cre...        Robert Wise
# 10848  Stephen Boyd|Raquel Welch|Edmond O'Brien|Donal...  Richard Fleischer
#
#                                                  tagline  runtime
# 0                                      The park is open.      124  \
# 1                                     What a Lovely Day.      120
# 2                             One Choice Can Destroy You      119
# 3                          Every generation has a story.      136
# 4                                    Vengeance Hits Home      137
# ...                                                  ...      ...
# 10822  You are cordially invited to George and Martha...      131
# 10828                  It tears you apart with suspense!      128
# 10829                  It's the Big One with the Big Two      120
# 10835  This is the heroic story of the men on the U.S...      182
# 10848  A Fantastic and Spectacular Voyage... Through ...      100
#
#                                           genres release_date  release_year
# 0      Action|Adventure|Science Fiction|Thriller   2015-06-09          2015  \
# 1      Action|Adventure|Science Fiction|Thriller   2015-05-13          2015
# 2             Adventure|Science Fiction|Thriller   2015-03-18          2015
# 3       Action|Adventure|Science Fiction|Fantasy   2015-12-15          2015
# 4                          Action|Crime|Thriller   2015-04-01          2015
# ...                                          ...          ...           ...
# 10822                                      Drama   2066-06-21          1966
# 10828                           Mystery|Thriller   2066-07-13          1966
# 10829                             Action|Western   2066-12-17          1966
# 10835         Action|Adventure|Drama|War|Romance   2066-12-20          1966
# 10848                  Adventure|Science Fiction   2066-08-24          1966
#
#            profit
# 0      1363528810
# 1       228436354
# 2       185238201
# 3      1868178225
# 4      1316249360
# ...           ...
# 10822    26236689
# 10828    10000000
# 10829     1347000
# 10835     8000000
# 10848     6885000
#
# [3854 rows x 12 columns]

# %%
# determine value of max and min profit
tmdb_data['profit'].max() , tmdb_data['profit'].min()
# Out:
# (2544505847, -413912431)

# %% [markdown]
# the highest earned profit = 2544505847 .
# the lowest earned profit = -413912431

# %%
#showing the row that contain the highest profit 
tmdb_data.query('profit == 2544505847 ')
# Out:
#       popularity     budget     revenue original_title
# 1386    9.432768  237000000  2781505847         Avatar  \
#
#                                                    cast       director
# 1386  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron  \
#
#                           tagline  runtime
# 1386  Enter the World of Pandora.      162  \
#
#                                         genres release_date  release_year
# 1386  Action|Adventure|Fantasy|Science Fiction   2009-12-10          2009  \
#
#           profit
# 1386  2544505847

# %%
#showing the row that contain lowest profit 

tmdb_data.query('profit == -413912431 ')
# Out:
#       popularity     budget   revenue     original_title
# 2244     0.25054  425000000  11087569  The Warrior's Way  \
#
#                                                    cast    director
# 2244  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee  \
#
#                       tagline  runtime
# 2244  Assassin. Hero. Legend.      100  \
#
#                                          genres release_date  release_year
# 2244  Adventure|Fantasy|Action|Western|Thriller   2010-12-02          2010  \
#
#          profit
# 2244 -413912431

# %% [markdown]
# Column with id 1386 shows the highest earned profit i.e 2544505847 .
#
# Whereas the column with id 2244 shows the lowest earned profit i.e -413912431

# %% [markdown]
# the move with hightest profit is Avatar , the lowest is The Warrior's Way

# %%
tmdb_data['profit'].mean()
# Out:
# 70482919.14322782

# %% [markdown]
# ## Movies with longest and shortest runtime values

# %%
# determine value of max and min runtime
tmdb_data['runtime'].max() , tmdb_data['runtime'].min()
# Out:
# (338, 15)

# %%
#showing the row that contain the longest runtime value 

tmdb_data.query('runtime == 338 ')
# Out:
#       popularity    budget  revenue original_title
# 2107    0.534192  18000000   871279         Carlos  \
#
#                                                    cast         director
# 2107  Edgar RamÃ­rez|Alexander Scheer|Fadi Abi Samra...  Olivier Assayas  \
#
#                              tagline  runtime                        genres
# 2107  The man who hijacked the world      338  Crime|Drama|Thriller|History  \
#
#      release_date  release_year    profit
# 2107   2010-05-19          2010 -17128721

# %%
#showing the row that contain the shortest runtime value 

tmdb_data.query('runtime == 15 ')
# Out:
#       popularity  budget  revenue original_title
# 5162    0.208637      10        5    Kid's Story  \
#
#                                                    cast             director
# 5162  Clayton Watson|Keanu Reeves|Carrie-Anne Moss|K...  Shinichiro Watanabe  \
#
#      tagline  runtime                     genres release_date  release_year
# 5162     NaN       15  Science Fiction|Animation   2003-06-02          2003  \
#
#       profit
# 5162      -5

# %% [markdown]
# Column with id 2107 shows the longest runtime = 338 minutes.
#
# Whereas the column with id 5162 shows the shortest runtime = 15 minutes
#
# the move with hightest profit is Carlos , the lowest is The Kid's Story

# %%
tmdb_data['runtime'].mean()
# Out:
# 109.22029060716139

# %% [markdown]
# ## Most Frequent star cast

# %%
data = tmdb_data['cast'].str.cat(sep = '|')

data = pd.Series(data.split('|'))

count = data.value_counts(ascending = False)
count
# Out:
# Robert De Niro       52
# Bruce Willis         46
# Samuel L. Jackson    44
# Nicolas Cage         43
# Matt Damon           36
#                      ..
# Zoe Aggeliki          1
# Jan Broberg           1
# Matt Bush             1
# Katrina Bowden        1
# Raquel Welch          1
# Name: count, Length: 6839, dtype: int64

# %% [markdown]
# ## Successful genres that have high profit

# %%
# create new dataframe according the highest 1500 profit
profit_ana = tmdb_data.nlargest(1500 ,'profit')
profit_ana
# Out:
#       popularity     budget     revenue                        original_title
# 1386    9.432768  237000000  2781505847                                Avatar  \
# 3      11.173104  200000000  2068178225          Star Wars: The Force Awakens
# 5231    4.355219  200000000  1845034188                               Titanic
# 0      32.985763  150000000  1513528810                        Jurassic World
# 4       9.335014  190000000  1506249360                             Furious 7
# ...          ...        ...         ...                                   ...
# 4426    1.306241   40000000    79700000  What to Expect When You're Expecting
# 3970    0.936666   75000000   114660784                      We Were Soldiers
# 2684    0.875299   35000000    74558115                             From Hell
# 3515    0.785489   24000000    63543328                             Footloose
# 2669    1.065364   25000000    64437847                    Kiss of the Dragon
#
#                                                    cast
# 1386  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  \
# 3     Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 5231  Kate Winslet|Leonardo DiCaprio|Frances Fisher|...
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 4     Vin Diesel|Paul Walker|Jason Statham|Michelle ...
# ...                                                 ...
# 4426  Cameron Diaz|Jennifer Lopez|Elizabeth Banks|An...
# 3970  Mel Gibson|Greg Kinnear|Madeleine Stowe|Sam El...
# 2684  Johnny Depp|Heather Graham|Ian Holm|Robbie Col...
# 3515  Kenny Wormald|Julianne Hough|Dennis Quaid|Andi...
# 2669  Jet Li|Bridget Fonda|TchÃ©ky Karyo|Max Ryan|Ri...
#
#                         director
# 1386               James Cameron  \
# 3                    J.J. Abrams
# 5231               James Cameron
# 0                Colin Trevorrow
# 4                      James Wan
# ...                          ...
# 4426                  Kirk Jones
# 3970             Randall Wallace
# 2684  Albert Hughes|Allen Hughes
# 3515                Craig Brewer
# 2669                 Chris Nahon
#
#                                                 tagline  runtime
# 1386                        Enter the World of Pandora.      162  \
# 3                         Every generation has a story.      136
# 5231          Nothing on Earth could come between them.      194
# 0                                     The park is open.      124
# 4                                   Vengeance Hits Home      137
# ...                                                 ...      ...
# 4426                     It's too late to pull out now.      110
# 3970  400 U.S paratroopers. 4000 Vietnamese soldiers...      138
# 2684                      Only the legend will survive.      122
# 3515                   There comes a time to cut loose.      113
# 2669                                  Kiss Fear Goodbye       98
#
#                                          genres release_date  release_year
# 1386   Action|Adventure|Fantasy|Science Fiction   2009-12-10          2009  \
# 3      Action|Adventure|Science Fiction|Fantasy   2015-12-15          2015
# 5231                     Drama|Romance|Thriller   1997-11-18          1997
# 0     Action|Adventure|Science Fiction|Thriller   2015-06-09          2015
# 4                         Action|Crime|Thriller   2015-04-01          2015
# ...                                         ...          ...           ...
# 4426                       Romance|Comedy|Drama   2012-05-17          2012
# 3970                         Action|History|War   2002-03-01          2002
# 2684                    Horror|Mystery|Thriller   2001-10-19          2001
# 3515                        Drama|Music|Romance   2011-10-06          2011
# 2669                      Action|Crime|Thriller   2001-07-06          2001
#
#           profit
# 1386  2544505847
# 3     1868178225
# 5231  1645034188
# 0     1363528810
# 4     1316249360
# ...          ...
# 4426    39700000
# 3970    39660784
# 2684    39558115
# 3515    39543328
# 2669    39437847
#
# [1500 rows x 12 columns]

# %%
# take a column, and separate the string by '|'
suc_genre = profit_ana['genres'].str.cat(sep = '|')
#giving suc_genre series and storing the values separately
suc_genre = pd.Series(suc_genre.split('|'))
#counting and arranging in descending order
suc_genre = suc_genre.value_counts(ascending = False)

suc_genre
# Out:
# Drama              557
# Comedy             544
# Action             507
# Thriller           457
# Adventure          402
# Romance            247
# Family             242
# Crime              228
# Science Fiction    219
# Fantasy            212
# Horror             143
# Animation          129
# Mystery            122
# Music               54
# War                 50
# History             47
# Western             16
# Documentary          6
# Foreign              1
# Name: count, dtype: int64

# %%
# Draw the pie chart of genres
# lt = suc_genre.plot.pie()
sizes = suc_genre.values
labels = suc_genre.index

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%')
ax1.axis('equal')
plt.title('The percentage of each genre')
# Out:
# Text(0.5, 1.0, 'The percentage of each genre')

# %% [markdown]
# from the pie chart and analysis
# Drama is the most profit genre

# %% [markdown]
# ## kinds of properties are associated with movies that have high revenues?

# %%
# create new dataframe according the highest 1000 revenues
df = tmdb_data.nlargest(1000 ,'revenue')
df.head(3)
# Out:
#       popularity     budget     revenue                original_title
# 1386    9.432768  237000000  2781505847                        Avatar  \
# 3      11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 5231    4.355219  200000000  1845034188                       Titanic
#
#                                                    cast       director
# 1386  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron  \
# 3     Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...    J.J. Abrams
# 5231  Kate Winslet|Leonardo DiCaprio|Frances Fisher|...  James Cameron
#
#                                         tagline  runtime
# 1386                Enter the World of Pandora.      162  \
# 3                 Every generation has a story.      136
# 5231  Nothing on Earth could come between them.      194
#
#                                         genres release_date  release_year
# 1386  Action|Adventure|Fantasy|Science Fiction   2009-12-10          2009  \
# 3     Action|Adventure|Science Fiction|Fantasy   2015-12-15          2015
# 5231                    Drama|Romance|Thriller   1997-11-18          1997
#
#           profit
# 1386  2544505847
# 3     1868178225
# 5231  1645034188

# %%
plt.scatter(x=df['revenue'], y=df['budget']),

# df.hist(figsize = (30, 30));
# Out:
# (<matplotlib.collections.PathCollection at 0x14467317ad0>,)

# %%
plt.scatter(x=df['revenue'], y=df['popularity']),
# Out:
# (<matplotlib.collections.PathCollection at 0x144673165d0>,)

# %%
plt.scatter(x=df['revenue'], y=df['runtime']),
# Out:
# (<matplotlib.collections.PathCollection at 0x144673f5ad0>,)

# %%
plt.scatter(x=df['revenue'], y=df['release_year']),
# Out:
# (<matplotlib.collections.PathCollection at 0x144675a1dd0>,)

# %%
plt.scatter(x=df['revenue'], y=df['profit'])

# %%
df.describe()
# Out:
#         popularity        budget       revenue     runtime
# count  1000.000000  1.000000e+03  1.000000e+03  1000.00000  \
# mean      2.284820  7.768619e+07  3.126380e+08   116.06200
# min       0.131526  1.500000e+04  1.197543e+08    72.00000
# 25%       1.119466  3.500000e+07  1.617358e+08   100.00000
# 50%       1.677315  6.500000e+07  2.254269e+08   114.00000
# 75%       2.632429  1.050000e+08  3.620530e+08   129.00000
# max      32.985763  3.800000e+08  2.781506e+09   201.00000
# std       2.290748  5.543574e+07  2.456472e+08    21.31996
#
#                      release_date  release_year        profit
# count                        1000   1000.000000  1.000000e+03
# mean   2004-11-04 01:20:38.400000   2003.567000  2.349519e+08
# min           1973-07-05 00:00:00   1961.000000 -2.403752e+07
# 25%           1998-12-16 12:00:00   1998.000000  1.083782e+08
# 50%           2006-04-17 12:00:00   2005.000000  1.596443e+08
# 75%           2011-07-10 12:00:00   2011.000000  2.778136e+08
# max           2072-03-15 00:00:00   2015.000000  2.544506e+09
# std                           NaN      9.211208  2.192727e+08

# %%
df[['popularity', 'revenue']].corr()
# Out:
#             popularity   revenue
# popularity    1.000000  0.516213
# revenue       0.516213  1.000000

# %%
df[['runtime', 'revenue']].corr()
# Out:
#           runtime   revenue
# runtime  1.000000  0.245629
# revenue  0.245629  1.000000

# %%
df.apply(pd.to_numeric, errors='coerce').corr()
# Out:
#                 popularity    budget   revenue  original_title  cast
# popularity        1.000000  0.319683  0.516213             1.0   NaN  \
# budget            0.319683  1.000000  0.563062             1.0   NaN
# revenue           0.516213  0.563062  1.000000             1.0   NaN
# original_title    1.000000  1.000000  1.000000             1.0   NaN
# cast                   NaN       NaN       NaN             NaN   NaN
# director               NaN       NaN       NaN             NaN   NaN
# tagline                NaN       NaN       NaN             NaN   NaN
# runtime           0.224130  0.222044  0.245629             1.0   NaN
# genres                 NaN       NaN       NaN             NaN   NaN
# release_date      0.212573  0.292090  0.119550             1.0   NaN
# release_year      0.225617  0.420965  0.174274             1.0   NaN
# profit            0.497483  0.377971  0.977930             1.0   NaN
#
#                 director  tagline   runtime  genres  release_date
# popularity           NaN      NaN  0.224130     NaN      0.212573  \
# budget               NaN      NaN  0.222044     NaN      0.292090
# revenue              NaN      NaN  0.245629     NaN      0.119550
# original_title       NaN      NaN  1.000000     NaN      1.000000
# cast                 NaN      NaN       NaN     NaN           NaN
# director             NaN      NaN       NaN     NaN           NaN
# tagline              NaN      NaN       NaN     NaN           NaN
# runtime              NaN      NaN  1.000000     NaN     -0.047653
# genres               NaN      NaN       NaN     NaN           NaN
# release_date         NaN      NaN -0.047653     NaN      1.000000
# release_year         NaN      NaN -0.073951     NaN      0.629486
# profit               NaN      NaN  0.219038     NaN      0.060084
#
#                 release_year    profit
# popularity          0.225617  0.497483
# budget              0.420965  0.377971
# revenue             0.174274  0.977930
# original_title      1.000000  1.000000
# cast                     NaN       NaN
# director                 NaN       NaN
# tagline                  NaN       NaN
# runtime            -0.073951  0.219038
# genres                   NaN       NaN
# release_date        0.629486  0.060084
# release_year        1.000000  0.088809
# profit              0.088809  1.000000

# %% [markdown]
# ## Which genres are most popular from year to year?

# %%
#storing ['release_year', 'genres', 'popularity'] in a new DataFrame called df_genres:
df_genres = tmdb_data[['release_year', 'genres', 'popularity']]
df_genres
# Out:
#        release_year                                     genres  popularity
# 0              2015  Action|Adventure|Science Fiction|Thriller   32.985763
# 1              2015  Action|Adventure|Science Fiction|Thriller   28.419936
# 2              2015         Adventure|Science Fiction|Thriller   13.112507
# 3              2015   Action|Adventure|Science Fiction|Fantasy   11.173104
# 4              2015                      Action|Crime|Thriller    9.335014
# ...             ...                                        ...         ...
# 10822          1966                                      Drama    0.670274
# 10828          1966                           Mystery|Thriller    0.402730
# 10829          1966                             Action|Western    0.395668
# 10835          1966         Action|Adventure|Drama|War|Romance    0.299911
# 10848          1966                  Adventure|Science Fiction    0.207257
#
# [3854 rows x 3 columns]

# %%
# split the genres string
df_genres.genres = tmdb_data.genres.str.split('|')
# # create genre list( create each row for each gen) using explode 
df_genres = df_genres.explode('genres')
df_genres

# groupby year again and get the largest value
data = df_genres.groupby(['release_year','genres'])['popularity'].mean().groupby(level='release_year').nlargest(1).reset_index(level=0, drop=True)
# change the series to dataframe
data = data.reset_index()
data
# Out:
#     release_year           genres  popularity
# 0           1960           Horror    2.610362
# 1           1961        Animation    2.631987
# 2           1962         Thriller    3.170651
# 3           1963           Action    1.357698
# 4           1964           Action    3.153791
# 5           1965         Thriller    1.910465
# 6           1966          Mystery    0.402730
# 7           1967        Animation    2.550704
# 8           1968          Mystery    1.728887
# 9           1969           Action    1.778746
# 10          1970        Animation    1.936962
# 11          1971           Family    2.430667
# 12          1972            Drama    1.109904
# 13          1973        Animation    2.272486
# 14          1974          Mystery    1.387058
# 15          1975        Adventure    2.399072
# 16          1976           Horror    0.914588
# 17          1977  Science Fiction    1.756893
# 18          1978           Action    0.595022
# 19          1979           Horror    4.475760
# 20          1980        Adventure    2.271940
# 21          1981           Action    1.286448
# 22          1982          Mystery    1.748637
# 23          1983        Adventure    1.220253
# 24          1984           Family    1.980175
# 25          1985  Science Fiction    1.336467
# 26          1986         Thriller    1.148817
# 27          1987            Music    1.574786
# 28          1988           Family    1.422091
# 29          1989  Science Fiction    1.910187
# 30          1990          Western    1.695911
# 31          1991        Animation    2.148455
# 32          1992        Animation    3.966538
# 33          1993              War    1.625452
# 34          1994            Drama    1.281754
# 35          1995        Animation    2.059539
# 36          1996        Animation    1.487220
# 37          1997        Animation    2.430244
# 38          1998        Animation    1.957596
# 39          1999          Fantasy    1.397588
# 40          2000          Fantasy    1.258769
# 41          2001          Fantasy    2.026693
# 42          2002          Fantasy    2.034891
# 43          2003          Fantasy    2.146595
# 44          2004          Fantasy    1.849154
# 45          2005  Science Fiction    1.499677
# 46          2006            Music    2.212338
# 47          2007           Family    1.808575
# 48          2008          Fantasy    1.449915
# 49          2009              War    4.341473
# 50          2010          Mystery    2.180953
# 51          2011  Science Fiction    1.896193
# 52          2012          Western    5.944518
# 53          2013  Science Fiction    2.615275
# 54          2014  Science Fiction    5.971291
# 55          2015  Science Fiction    8.418798

# %%
# Draw the scatterplot to show the change of the most popular genre
plt.scatter(data.release_year, data.genres)
plt.title('The change of the most popular genre over the year')
plt.xlabel('Year')
plt.ylabel('Genre')

plt.show()

# %% [markdown]
# From the scatterplot above, it is easy to show that the most popular genre changed over the year. However, in some periods there are no or little changes. Overall, the most popular genre in 1990s is animation, while it becomes fantasy in 2000s.

# %% [markdown]
# ## Conclusions
